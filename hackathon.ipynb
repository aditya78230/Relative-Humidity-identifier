# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_data = pd.read_csv("train_data.csv")
train_data = train_data.drop(columns=['Date', 'Time'])

# %%
test_data = pd.read_csv("test_data.csv")
test_data = test_data.drop(columns=['Date', 'Time', 'Unnamed: 0'])

# %%
X_train = train_data.drop(columns=['RH_type'])
y_train = train_data['RH_type']

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf_classifier.predict(test_data)

# %%
test_data['Predicted_RH_type'] = y_pred

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=test_data, x='Predicted_RH_type', palette=custom_palette)
plt.title("Predicted Distribution of RH_type in Testing Data")
plt.xlabel("Predicted RH_type")
plt.ylabel("Count")
plt.show()
# Out:
# <ipython-input-24-cc6a3589ba09>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=test_data, x='Predicted_RH_type', palette=custom_palette)

# %%
test_ids = test_data['id']
output_df = pd.DataFrame({'id': test_ids, 'RH_type': y_pred})
output_df.to_csv("predicted_output.csv", index=False)
print("ID,Predicted_RH_type")
for index, row in output_df.iterrows():
    print(f"{row['id']},{row['RH_type']}")
# Out:
# ID,Predicted_RH_type
# 1,Ideal
# 2,Ideal
# 3,Ideal
# 4,Ideal
# 5,Ideal
# 6,Ideal
# 7,Ideal
# 8,Ideal
# 9,Ideal
# 10,Ideal
# 11,Dry
# 12,Dry
# 13,Dry
# 14,Ideal
# 15,Ideal
# 16,Ideal
# 17,Ideal
# 18,Ideal
# 19,Ideal
# 20,Ideal
# 21,Ideal
# 22,Ideal
# 23,Ideal
# 24,Ideal
# 25,Ideal
# 26,Ideal
# 27,Ideal
# 28,Ideal
# 29,Ideal
# 30,Ideal
# 31,Ideal
# 32,Ideal
# 33,Ideal
# 34,Ideal
# 35,Ideal
# 36,Ideal
# 37,Dry
# 38,Dry
# 39,Dry
# 40,Dry
# 41,Dry
# 42,Dry
# 43,Dry
# 44,Dry
# 45,Dry
# 46,Dry
# 47,Dry
# 48,Dry
# 49,Dry
# 50,Dry
# 51,Dry
# 52,Dry
# 53,Dry
# 54,Dry
# 55,Dry
# 56,Dry
# 57,Dry
# 58,Dry
# 59,Dry
# 60,Dry
# 61,Dry
# 62,Dry
# 63,Dry
# 64,Dry
# 65,Dry
# 66,Dry
# 67,Dry
# 68,Dry
# 69,Dry
# 70,Dry
# 71,Dry
# 72,Dry
# 73,Dry
# 74,Dry
# 75,Dry
# 76,Dry
# 77,Dry
# 78,Dry
# 79,Dry
# 80,Dry
# 81,Dry
# 82,Dry
# 83,Dry
# 84,Dry
# 85,Dry
# 86,Dry
# 87,Dry
# 88,Dry
# 89,Dry
# 90,Dry
# 91,Dry
# 92,Dry
# 93,Dry
# 94,Dry
# 95,Dry
# 96,Dry
# 97,Dry
# 98,Dry
# 99,Dry
# 100,Dry
# 101,Dry
# ...

# %%
from google.colab import files
files.download('predicted_output.csv')
